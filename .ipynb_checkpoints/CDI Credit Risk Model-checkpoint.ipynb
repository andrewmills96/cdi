# %% [markdown]
# **Environment**

# %%
# %pip install pandas numpy matplotlib seaborn scipy tabulate

# %%
# %pip install --upgrade pip

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import importlib
import sys
from pathlib import Path

# Add current directory to path
sys.path.insert(0, str(Path.cwd()))

# Set up automatic module reloading on every cell execution
from IPython.core.getipython import get_ipython

def auto_reload_model():
    if 'model' in sys.modules:
        importlib.reload(sys.modules['model'])

ipython = get_ipython()
if ipython:
    ipython.events.register('pre_execute', auto_reload_model)

from model import *

# %% [markdown]
# **Input Data**

# %%
# Data path
project_root = Path.cwd()
data_path = project_root / "data"

# Liabilities
liabilities_df = pd.read_csv(data_path / 'liabs.csv', parse_dates=['date'], dayfirst=True, index_col = 'date')
liabilities = Liabilities(
    dates=liabilities_df.index.to_list(),
    cashflows=liabilities_df['cashflow']
)

# German Goverment Bond (Bund) Yields
bund_yields = pd.read_csv(data_path / 'bund_yields.csv', parse_dates=['date'], index_col = 'date')
rates = Rates(bund_yields['yield'].to_numpy(), bund_yields.index.to_list())

# Spreads
spreads_df = pd.read_csv(data_path / 'credit_spreads.csv', index_col='rating')
spread_map = spreads_df['spread'].to_dict()

# Issuers
issuers_df = pd.read_csv(data_path / 'issuers.csv', dtype={'id': 'str'}, index_col='id')
issuers = Issuers(
    ids=issuers_df.index.to_list(),
    ratings=issuers_df['rating'],
    sectors=issuers_df['sector'],
    names = issuers_df['name']
)

# Bonds
bond_data = pd.read_csv(data_path / 'bonds.csv', dtype={'id': 'str', 'issuer_id': 'str'}, index_col='id')
cashflow_ladder = pd.read_csv(data_path / 'cashflow_ladder.csv', parse_dates=['date'], dayfirst=True).set_index('date')
bonds = Bonds(
    ids = bond_data.index.to_list(),
    issuer_ids = bond_data['issuer_id'],
    recoveries = bond_data['recovery'],
    cashflows = cashflow_ladder,
    issuers = issuers
)

# Transition matrix
tmatrix = pd.read_csv(data_path / 'transition_matrix.csv')
transition_matrix = TransitionMatrix(
    tmatrix = tmatrix.values,
    labels = tmatrix.columns.to_list()
)

# Economy and Sector correlations
rho_e = .24
rho_s = np.array([rho_e])   # Match economy correlation to remove sector impact

# Model object
cr_model = CreditRiskModel(
    transition_matrix = transition_matrix,
    rho_e = rho_e,
    rho_s = rho_s,
    issuer_ids = issuers.ids,
    sector_map = issuers.sectors,
    ratings_map = issuers.ratings
)

# %% [markdown]
# **Mandate Config**

# %%
# Valuation Date
val_date = pd.to_datetime('01-01-2026', dayfirst = True)

# Bond Allocations (Notionals per Bond ID)
cdi_allocation = pd.read_csv(data_path / 'cdi_allocation.csv', index_col = 'id').iloc[:, 0]
cmbp_allocation = pd.read_csv(data_path / 'cmbp_allocation.csv', index_col = 'id').iloc[:, 0]

# Starting Cash Value
cash = 5e06

# Mandate Parameters
config = FoxConfig(
    heubeck_liabilities= 297_033_196,
    r_gaap = 0.0201,
    r_ifrs = 0.039,
    mortality_buffer = 1.0559,
    cmbp_margin = 0.001,
    fee = 0.003,
    asset_buffer = 12.5e06,
    performance_cap = 50e06
)

# CDI Object
cdi_fox = CDIMandate_Fox(
    liabilities=liabilities,
    cash=cash,
    bonds=bonds,
    cdi_allocation=cdi_allocation,
    cmbp_allocation=cmbp_allocation,
    config=config
)

# %% [markdown]
# **Run**

# %%
# Simulate Economy
np.random.seed(123)
n_sim = 5000
n_years = 25
sim_results = cr_model.run(n_sim, n_years)

# Simulate CDI Solution
cdi_sim_results = cdi_fox.run(val_date, rates, spread_map, sim_results)

# %% [markdown]
# **Performance against bund comparator**

# %%
cdi_sim = cdi_sim_results.cdi_sim

### summary table ###
date = '2050-12-31'
qs = [0.005, 0.05, 0.25, 0.50, 0.75, 0.95, 0.995]
fields = ['assets', 'bund_comparator', 'performance_payment']
df = (
    cdi_sim.loc[cdi_sim["date"].eq(date), fields]
    .rename({'assets': 'Assets', 'bund_comparator': 'Bund Comparator', 'performance_payment': 'Performance Payment'})
    .quantile(qs)
    .T
    )
print(date)
print(df.to_markdown(floatfmt = ',.0f'))

### plot ###
errorbar = ('pi', 99)

fig, ax = plt.subplots(1,3, figsize = (20,5), sharex = True, sharey=True)

sns.lineplot(cdi_sim, x = 'date', y = 'assets', errorbar = errorbar, label = 'Assets', ax = ax[0])
sns.lineplot(cdi_sim, x = 'date', y = 'bund_comparator', errorbar = errorbar, label = 'Bund Comparator', ax = ax[0])
sns.barplot(cdi_sim, x = 'date', y = 'performance_payment', native_scale=True, errorbar=errorbar, label = 'Performance Payment', ax = ax[0])
ax[0].set_title('Asset Performance')
ax[0].set_ylabel('\N{EURO SIGN}')

sns.lineplot(cdi_sim, x = 'date', y = 'assets', errorbar = errorbar, label = 'Assets', ax = ax[1])
sns.lineplot(cdi_sim, x = 'date', y = 'meltdown_liabilities', errorbar = errorbar, label = 'Meltdown Liabilities', ax = ax[1])
ax[1].set_title('Meltdown')

sns.lineplot(cdi_sim, x = 'date', y = 'assets', errorbar = errorbar, label = 'Assets', ax = ax[2])
sns.lineplot(cdi_sim, x = 'date', y = 'next_2_liabs', errorbar=errorbar, label = 'Next 2 Liabs', ax = ax[2])
sns.lineplot(cdi_sim, x = 'date', y = 'hgb_gap', errorbar = errorbar, label = 'HGB Gap', ax = ax[2])
sns.barplot(cdi_sim, x = 'date', y = 'hgb_payment', native_scale=True, errorbar=errorbar, label = 'HGB Payment', ax = ax[2])
ax[2].set_title('HGB Gap Coverage')

plt.show()
# Out:
# 2050-12-31
# |                     |      0.005 |       0.05 |       0.25 |        0.5 |       0.75 |       0.95 |      0.995 |
# |:--------------------|-----------:|-----------:|-----------:|-----------:|-----------:|-----------:|-----------:|
# | assets              | 59,526,799 | 70,573,252 | 76,218,037 | 78,192,778 | 79,947,154 | 80,142,014 | 80,237,077 |
# | bund_comparator     | 90,874,242 | 90,874,242 | 90,874,242 | 90,874,242 | 90,874,242 | 90,874,242 | 90,874,242 |
# | performance_payment | 10,637,164 | 10,732,227 | 10,927,088 | 12,681,463 | 14,656,204 | 20,300,990 | 31,347,442 |

# %% [markdown]
# **Tables**

# %%
# PV of Obligations
qs = [0.005, 0.05, 0.25, 0.50, 0.75, 0.95, 0.995]
pv = (
    cdi_sim.assign(
        performance_payment=lambda d: d.performance_payment*(1 + d.bund_yield)**(-d.dt),
        fees=lambda d: d.fee*(1 + d.bund_yield)**(-d.dt),
        net= lambda d: d.fee - d.performance_payment,
        pv_hgb=lambda d: d.hgb_payment*(1+d.bund_yield)**(-d.dt)
    )
    .groupby("scenario")[[ "hgb_payment", "performance_payment","fees", "net"]].sum()
)
print("PV of Obligations Summary \n")
print(pv.quantile(qs).T.to_markdown(floatfmt = '.0f'), "\n")
print(f"Prob(Fees > Performance Payment) = {(pv.fees > pv.performance_payment).mean():.2%}")
print(f"E[PV(Performance Payment)] = {pv.performance_payment.mean()/1e06:.2f}m")
print('\n')

# Terminal Value distribution
date = '2050-12-31'

fields = ['liab_pv_gaap', 'assets', 'funding_level_gaap', 'funding_level_ifrs', 'CMBP', 'performance_payment']
df = cdi_sim.rename(columns={'bund_comparator': 'CMBP'}).loc[cdi_sim["date"].eq(date), fields].quantile(qs).T

print("Terminal Values Summary")
print(f"Date: {date}")
print(df.to_markdown(floatfmt='.2f'))
# Out:
# PV of Obligations Summary
#
# |                     |   0.005 |    0.05 |    0.25 |     0.5 |    0.75 |    0.95 |    0.995 |
# |:--------------------|--------:|--------:|--------:|--------:|--------:|--------:|---------:|
# | hgb_payment         |       0 |       0 |       0 |       0 |       0 |       0 |        0 |
# | performance_payment | 4494502 | 4534668 | 4617003 | 5358276 | 6192659 | 8577740 | 13245178 |
# | fees                | 9159071 | 9431921 | 9581512 | 9637056 | 9676065 | 9697769 |  9708195 |
# | net                 | -965899 | 4158476 | 6781915 | 7710992 | 8521622 | 8629013 |  8677480 |
#
# Prob(Fees > Performance Payment) = 96.88%
# E[PV(Performance Payment)] = 5.72m
#
#
# Terminal Values Summary
# Date: 2050-12-31
# |                     |         0.005 |          0.05 |          0.25 |           0.5 |          0.75 |          0.95 |         0.995 |
# ...

# %% [markdown]
# **Performace Payment Results**

# %%
fig, ax = plt.subplots(1,3, figsize = (14,4), sharey=True, sharex=False)

sns.histplot(
    pv.performance_payment, bins=100, kde = False,
    cumulative=True, stat = 'density', log_scale=False,
    fill = False, element="poly", ax = ax[0]
).set(xlabel = 'PV Performance Payment')

sns.histplot(
    pv.fees, bins=100, kde = False,
    cumulative=True, stat = 'density', log_scale=False,
    fill = False, element="poly", ax = ax[1]
).set(xlabel = 'PV Fees')


sns.histplot(
    pv.net, bins=100, kde = False,
    cumulative=True, stat = 'density', log_scale=False,
    fill = False, element="poly", ax = ax[2]
).set(xlabel = 'PV Net')

plt.suptitle('PV of Performance Payment vs Fees')
plt.show()
